# %%
bronze_parameters = [
    {
        "folders" : "products_first",
        "file_name" : "products",
        "checkpoint_name" : "checkpoint_products"
    },
    {
        "folders" : "customers_first",
        "file_name" : "customers",
        "checkpoint_name" : "checkpoint_customers"
    },

    {
        "folders" : "regions",
        "file_name" : "regions",
        "checkpoint_name" : "checkpoint_regions"
    }
]

# %%
dbutils.jobs.taskValues.set("bronze_parameters", bronze_parameters)
