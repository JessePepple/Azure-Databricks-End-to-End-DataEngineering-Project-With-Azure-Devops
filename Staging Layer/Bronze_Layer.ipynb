# %% [markdown]
# Parameterisation

# %%
dbutils.widgets.text("folders", "")
dbutils.widgets.text("file_name", "")
dbutils.widgets.text("checkpoint_name", "")

# %%
dbutils.widgets.get("folders")
dbutils.widgets.get("file_name")
dbutils.widgets.get("checkpoint_name")

# %%
folders = dbutils.widgets.get("folders")
file_name = dbutils.widgets.get("file_name")
checkpoint_name = dbutils.widgets.get("checkpoint_name")

# %% [markdown]
# ### Data Reading With SparkStreaming to our staging layer

# %%
df = spark.readStream.format("cloudfiles").option("cloudfiles.format", "parquet").option("cloudfiles.schemalocation", f"abfss://bronze@azuredatabricksjesslake.dfs.core.windows.net/{checkpoint_name}").load(f"abfss://src@azuredatabricksjesslake.dfs.core.windows.net/{folders}")

# %%
df.writeStream.format("parquet").outputMode("append").option("CheckPointLocation", f"abfss://bronze@azuredatabricksjesslake.dfs.core.windows.net/{checkpoint_name}").option("path", f"abfss://bronze@azuredatabricksjesslake.dfs.core.windows.net/{file_name}").trigger(once=True).start()

# %%
df = spark.read.format("")
