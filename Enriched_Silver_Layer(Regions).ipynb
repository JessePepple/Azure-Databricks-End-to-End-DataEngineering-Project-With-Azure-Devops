# %%
df = df = spark.read.format("parquet").load("abfss://bronze@azuredatabricksjesslake.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta").load("abfss://silver@azuredatabricksjesslake.dfs.core.windows.net/products")

df.display()

# %%
df.display()

# %%
df = df.drop("_rescued_data")
df.display()

# %%
df.write.format("delta").mode("overwrite").option("path", "abfss://silver@azuredatabricksjesslake.dfs.core.windows.net/regions").saveAsTable("dtbproject.silver.regions")
